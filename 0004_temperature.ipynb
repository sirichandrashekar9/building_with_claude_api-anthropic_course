# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

def add_user_message(messages, text):
    message = {"role": "user", "content": text}
    messages.append(message)
    return messages

def add_assistant_message(messages, text):
    message = {"role": "assistant", "content": text}
    messages.append(message)
    return messages

def chat(messages, system=None, temperature=1):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """ 
You are a creative movie story writer
"""

add_user_message(messages, "Write a movie story in one sentence")

answer = chat(messages, system, 1)

answer
# Out:
# 'When a lonely lighthouse keeper discovers that each ship he guides to safety with his beacon actually carries passengers from different time periods who are fleeing the same mysterious cosmic disaster, he must decide whether to keep saving them one by one or extinguish his light forever to prevent the catastrophe from spreading across all of time.'
